# %% [markdown]
# Use `!` to write in the command line.

# %%
# !ls
# Out:
# continent_facts.csv   encoding
# countries.csv         intro_to_pandas.ipynb

# %%
# !pwd
# Out:
# /Users/laurabejderjensen/Desktop/columbia_j_school/foundations_of_computing/class_5/05-classwork

# %%
# I installed pandas
# !pip install pandas

# %%
import pandas as pd

# %%
# But the right way is to do like this
# pd.read_csv("countries.csv")

# %%
# Save it as a variable called df (short for dataframe)

df = pd.read_csv("countries.csv")
df
# Out:
#                  country   continent  life_expectancy  population  \
# 0            Afghanistan        Asia           54.863    22856302
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 3                 Angola      Africa           45.234    13926373
# 4    Antigua and Barbuda  N. America           73.544       77656
# ..                   ...         ...              ...         ...
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
# 185          Yemen, Rep.        Asia           60.404    17723186
# 186               Zambia      Africa           41.802    10201562
# 187             Zimbabwe      Africa           43.976    12509477
#
#               gdp
# 0     15153728226
# 1     12886435920
# 2    155661450046
# 3     34063908358
# 4       989182128
# ..            ...
# 183  124201381770
# ...

# %%
# To get the number of rows and columns. 
df.shape
# Out:
# (188, 5)

# %%
# Look at the first five
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128

# %%
# Or the first 10
df.head(10)
# Out:
#                country   continent  life_expectancy  population           gdp
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128
# 5            Argentina  S. America           73.822    36930709  390394524839
# 6              Armenia      Europe           71.494     3076098    6502871172
# 7            Australia     Oceania           79.930    19164351  560384787591
# 8              Austria      Europe           78.330     8004712  256214821696
# 9           Azerbaijan      Europe           66.851     8110723   20544461359

# %% [markdown]
# To understand a method, put your cursor somewhere in the method, hold down shift and press tab tab

# %%
# Get the last 12
df.tail(12)
# Out:
#                   country   continent  life_expectancy  population  \
# 176  United Arab Emirates        Asia           74.163     3033491
# 177        United Kingdom      Europe           78.040    58874117
# 178         United States  N. America           76.800   282496310
# 179               Uruguay  S. America           74.777     3319066
# 180            Uzbekistan        Asia           66.999    24775610
# 181               Vanuatu     Oceania           67.438      185074
# 182             Venezuela  S. America           72.432    24348304
# 183               Vietnam        Asia           73.777    78758010
# 184    West Bank and Gaza        Asia           70.929     3198560
# 185           Yemen, Rep.        Asia           60.404    17723186
# 186                Zambia      Africa           41.802    10201562
# 187              Zimbabwe      Africa           43.976    12509477
#
#                 gdp
# 176     91041131892
# 177   1686390207348
# 178  11231488292980
# ...

# %% [markdown]
# # I dont have a lesson plan
# ## Is this actually true?
# Or is it even true at all
# > I turned this into a markdown cell. Now I can write as I want. **And it happened like magic!**

# %%
# Sort the data
df.sort_values(by='life_expectancy')
# Out:
#                   country continent  life_expectancy  population  \
# 147          Sierra Leone    Africa           38.123     4143115
# 186                Zambia    Africa           41.802    10201562
# 31   Central African Rep.    Africa           43.727     3701607
# 187              Zimbabwe    Africa           43.976    12509477
# 3                  Angola    Africa           45.234    13926373
# ..                    ...       ...              ...         ...
# 160                Sweden    Europe           79.840     8860153
# 7               Australia   Oceania           79.930    19164351
# 161           Switzerland    Europe           79.990     7167908
# 72       Hong Kong, China      Asia           80.361     6783317
# 83                  Japan      Asia           81.350   125720310
#
#                gdp
# 147     2141990455
# 186    10558616670
# 31      2820624534
# 187     9319560365
# 3      34063908358
# ..             ...
# 160   253754781920
# 7     560384787591
# ...

# %%
# By default sort values is ascending but we want the numbers to be descending
df.sort_values(by='life_expectancy', ascending = False)
# Out:
#                   country continent  life_expectancy  population  \
# 83                  Japan      Asia           81.350   125720310
# 72       Hong Kong, China      Asia           80.361     6783317
# 161           Switzerland    Europe           79.990     7167908
# 7               Australia   Oceania           79.930    19164351
# 160                Sweden    Europe           79.840     8860153
# ..                    ...       ...              ...         ...
# 3                  Angola    Africa           45.234    13926373
# 187              Zimbabwe    Africa           43.976    12509477
# 31   Central African Rep.    Africa           43.727     3701607
# 186                Zambia    Africa           41.802    10201562
# 147          Sierra Leone    Africa           38.123     4143115
#
#                gdp
# 83   3590446333290
# 72    203309577124
# 161   246475684488
# 7     560384787591
# 160   253754781920
# ..             ...
# 3      34063908358
# 187     9319560365
# ...

# %%
# What if we want a top-10? Just add .head(10)
df.sort_values(by='life_expectancy', ascending = False).head(10)
# Out:
#               country   continent  life_expectancy  population            gdp
# 83              Japan        Asia           81.350   125720310  3590446333290
# 72   Hong Kong, China        Asia           80.361     6783317   203309577124
# 161       Switzerland      Europe           79.990     7167908   246475684488
# 7           Australia     Oceania           79.930    19164351   560384787591
# 160            Sweden      Europe           79.840     8860153   253754781920
# 81              Italy      Europe           79.730    56986329  1547748695640
# 74            Iceland      Europe           79.720      281210     8743381320
# 29             Canada  N. America           79.410    30667365   995094659520
# 155             Spain      Europe           79.340    40288457   943152778370
# 57             France      Europe           79.230    59047795  1690892657620

# %%
# To get the last 2 out of the first 10 we just add tail(2)
df.sort_values(by='life_expectancy', ascending = False).head(10).tail(2)
# Out:
#     country continent  life_expectancy  population            gdp
# 155   Spain    Europe            79.34    40288457   943152778370
# 57   France    Europe            79.23    59047795  1690892657620

# %%
# To get a slice of the dataframe e.g. the things with the index of 90 to 102
df.loc[90:102]
# Out:
#             country continent  life_expectancy  population          gdp
# 90           Kuwait      Asia           73.133     1940786  70638788042
# 91       Kyrgyzstan      Asia           66.232     4954850   7566055950
# 92             Laos      Asia           61.689     5317060   8071297080
# 93           Latvia    Europe           70.160     2384972  20627622828
# 94          Lebanon      Asia           74.409     3742329  21686796555
# 95          Lesotho    Africa           47.265     1963878   2329159308
# 96          Liberia    Africa           52.424     2847290   1477743510
# 97            Libya    Africa           71.872     5231189  47807836271
# 98        Lithuania    Europe           72.180     3500028  33708769668
# 99       Luxembourg    Europe           77.820      435491  27838326684
# 100    Macao, China      Asia           77.627      431867   9722189904
# 101  Macedonia, FYR    Europe           73.244     2009091  14013409725
# ...

# %%
# If we only want Asian countries
df.continent == "Asia"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 183     True
# 184     True
# 185     True
# 186    False
# 187    False
# Name: continent, Length: 188, dtype: bool

# %%
# Feed the True/False series 
# Gives every row where something is true
df[df.continent == "Asia"]
# Out:
#                   country continent  life_expectancy  population  \
# 0             Afghanistan      Asia           54.863    22856302
# 11                Bahrain      Asia           74.497      638193
# 12             Bangladesh      Asia           65.309   129592275
# 18                 Bhutan      Asia           60.307      571262
# 23                 Brunei      Asia           75.927      327036
# 27               Cambodia      Asia           62.030    12446949
# 34                  China      Asia           72.124  1269116737
# 72       Hong Kong, China      Asia           80.361     6783317
# 75                  India      Asia           62.129  1053898107
# 76              Indonesia      Asia           67.289   213395411
# 77                   Iran      Asia           69.611    65342319
# 78                   Iraq      Asia           70.845    23857458
# 80                 Israel      Asia           78.750     6014953
# ...

# %%
# Same but instead we find all the countries with a life expectancy above 67
df[df.life_expectancy > 67]
# Out:
#                  country   continent  life_expectancy  population  \
# 1                Albania      Europe           74.200     3071856
# 2                Algeria      Africa           68.963    30533827
# 4    Antigua and Barbuda  N. America           73.544       77656
# 5              Argentina  S. America           73.822    36930709
# 6                Armenia      Europe           71.494     3076098
# ..                   ...         ...              ...         ...
# 179              Uruguay  S. America           74.777     3319066
# 181              Vanuatu     Oceania           67.438      185074
# 182            Venezuela  S. America           72.432    24348304
# 183              Vietnam        Asia           73.777    78758010
# 184   West Bank and Gaza        Asia           70.929     3198560
#
#               gdp
# 1     12886435920
# 2    155661450046
# 4       989182128
# 5    390394524839
# 6      6502871172
# ..            ...
# 179   30176948072
# ...

# %%
# We find the ten largest countries in Africa (by population)
df[df.continent == "Africa"] \
    .sort_values(by='population', ascending = False).head(10)
# Out:
#               country continent  life_expectancy  population           gdp
# 124           Nigeria    Africa           46.629   123688536  200251739784
# 49              Egypt    Africa           68.632    67648419  313144531551
# 54           Ethiopia    Africa           52.245    65577897   33575883264
# 37   Congo, Dem. Rep.    Africa           46.387    49626200   14490850400
# 153      South Africa    Africa           55.892    44760380  333643872520
# 165          Tanzania    Africa           50.010    34038161   28115520986
# 86              Kenya    Africa           52.864    31253701   41192377918
# 2             Algeria    Africa           68.963    30533827  155661450046
# 115           Morocco    Africa           68.220    28793236   88481614228
# 157             Sudan    Africa           57.979    27193105   50959878770

# %%
# NO ONE on the internet uses this!!!
df.query("continent == 'Europe'")
# Out:
#                     country continent  life_expectancy  population  \
# 1                   Albania    Europe        74.200000     3071856
# 6                   Armenia    Europe        71.494000     3076098
# 8                   Austria    Europe        78.330000     8004712
# 9                Azerbaijan    Europe        66.851000     8110723
# 14                  Belarus    Europe        68.990000    10057810
# 15                  Belgium    Europe        77.910000    10175684
# 20   Bosnia and Herzegovina    Europe        74.882000     3693698
# 24                 Bulgaria    Europe        71.590000     8006158
# 41                  Croatia    Europe        74.798000     4505533
# 43                   Cyprus    Europe        78.011000      943294
# 44               Czech Rep.    Europe        75.050000    10242890
# 45                  Denmark    Europe        76.900000     5339501
# 53                  Estonia    Europe        70.800000     1370749
# ...

# %%
# We try to calculate gdp per capita
df.gdp / df.population
# Out:
# 0        663.0
# 1       4195.0
# 2       5098.0
# 3       2446.0
# 4      12738.0
#         ...
# 183     1577.0
# 184     7586.0
# 185     2217.0
# 186     1035.0
# 187      745.0
# Length: 188, dtype: float64

# %%
# To greate gpd per capita as a new variable, do this:
df['gpd_per_capita'] = df.gdp / df.population

# And don't forget the []

# %%
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp  \
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128
#
#    gpd_per_capita
# 0           663.0
# 1          4195.0
# 2          5098.0
# 3          2446.0
# 4         12738.0

# %%
# We try to find the median gpd per capita
df.gpd_per_capita.median()
# Out:
# 5290.5

# %%
# And the same for the mean gdp per capita
df.gpd_per_capita.mean()
# Out:
# 9977.558510638299

# %%
# Step 1. find the average gpd per capita in asia
asian_mean = df[df.continent == "Asia"].gpd_per_capita.mean()
asian_mean
# Out:
# 11106.4375

# %%
# And then we find the countries where the continent is Africa AND where the 
# gpd per capita is lower than the mean gpd per capita in Asia
df[(df.continent == 'Africa') & (df.gpd_per_capita < asian_mean)]
# Out:
#                    country continent  life_expectancy  population  \
# 2                  Algeria    Africa          68.9630    30533827
# 3                   Angola    Africa          45.2340    13926373
# 17                   Benin    Africa          55.2610     6517810
# 21                Botswana    Africa          50.5670     1757925
# 25            Burkina Faso    Africa          50.5890    12294012
# 26                 Burundi    Africa          48.2510     6374347
# 28                Cameroon    Africa          51.9600    15678269
# 30              Cape Verde    Africa          69.8350      437238
# 31    Central African Rep.    Africa          43.7270     3701607
# 32                    Chad    Africa          46.7080     8222327
# 36                 Comoros    Africa          57.9000      562469
# 37        Congo, Dem. Rep.    Africa          46.3870    49626200
# 38             Congo, Rep.    Africa          52.3260     3135773
# ...

# %%
# Mean life expectancy
df.life_expectancy.mean()
# Out:
# 66.50153603526596

# %%
# Median life expectancy 
df.life_expectancy.median()
# Out:
# 70.04150000000001

# %%
# If I want to do a bunch of stuff at once
# .describe() summarizes the data
df.life_expectancy.describe()
# Out:
# count    188.000000
# mean      66.501536
# std       10.298458
# min       38.123000
# 25%       59.663750
# 50%       70.041500
# 75%       74.134500
# max       81.350000
# Name: life_expectancy, dtype: float64

# %%
# Count countries in each continent
df.continent.value_counts()
# If you want to count things, don't use groupby. Use value.counts !!!!!!!!!!
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: continent, dtype: int64

# %%
# We use groupby to get the median life expectancy for each continent.
df.groupby('continent').life_expectancy.median()
# Out:
# continent
# Africa        52.1025
# Asia          70.4275
# Europe        75.5800
# N. America    70.5765
# Oceania       67.4955
# S. America    70.7660
# Name: life_expectancy, dtype: float64

# %%
# Total population per continent.
df.groupby('continent').population.sum()
# Out:
# continent
# Africa         809892820
# Asia          3849172861
# Europe         596440013
# N. America     481999240
# Oceania         30272328
# S. America     347265096
# Name: population, dtype: int64

# %%
# Find the percentage
df.continent.value_counts(normalize=True)
# Out:
# Africa        0.287234
# Asia          0.255319
# Europe        0.223404
# N. America    0.117021
# S. America    0.063830
# Oceania       0.053191
# Name: continent, dtype: float64

# %%
# Find percentages that aren't decimals
df.continent.value_counts(normalize=True) * 100
# Out:
# Africa        28.723404
# Asia          25.531915
# Europe        22.340426
# N. America    11.702128
# S. America     6.382979
# Oceania        5.319149
# Name: continent, dtype: float64

# %%
# Create a new column with population in millions
df['pop_mio'] = df.population / 1000000
df.head()
# Out:
#                country   continent  life_expectancy  population           gdp  \
# 0          Afghanistan        Asia           54.863    22856302   15153728226
# 1              Albania      Europe           74.200     3071856   12886435920
# 2              Algeria      Africa           68.963    30533827  155661450046
# 3               Angola      Africa           45.234    13926373   34063908358
# 4  Antigua and Barbuda  N. America           73.544       77656     989182128
#
#    gpd_per_capita    pop_mio
# 0           663.0  22.856302
# 1          4195.0   3.071856
# 2          5098.0  30.533827
# 3          2446.0  13.926373
# 4         12738.0   0.077656

# %%
# 
df.gpd_per_capita.hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
#! pip install matplotlib

# %%
df.continent.value_counts().plot()
# Out:
# <AxesSubplot: >

# %%
# DO THIS IN YOUR HOMEWORK!!!!
df.continent.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
# How do we reverse it? We just included .sort_values()
df.continent.value_counts().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
# Scatterplot of the relationship between gdp per capita and life expectancy.
df.plot(kind='scatter', x='gpd_per_capita', y='life_expectancy')
# Out:
# <AxesSubplot: xlabel='gpd_per_capita', ylabel='life_expectancy'>

# %%
#! pip install altair

# %%
import altair as alt

# %%
alt.Chart(df).mark_circle().encode(
    x='gdp_per_capita',
    y='life_expectancy',
    color= 'country',
    size = 'population',
    tooltip = ['country', 'population']).interactive()
# Out:
# /Users/laurabejderjensen/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/altair/vegalite/v4/api.py:2020, in Chart.to_dict(self, *args, **kwargs)
#    2018     copy.data = core.InlineData(values=[{}])
#    2019     return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2020 return super().to_dict(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/altair/vegalite/v4/api.py:384, in TopLevelMixin.to_dict(self, *args, **kwargs)
#     381 kwargs["context"] = context
#     383 try:
# --> 384     dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
# ...
